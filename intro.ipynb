# %% [markdown]
# <a href="https://colab.research.google.com/github/koyamahr/retro-astro-jax/blob/main/intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🌌 Retro-Astro JAX Encyclopedia (RAJE)
#
# 〜 A Modern Computational Odyssey through Astrophysical History 〜
#
# プロジェクト概要:
#
# 1940年代から1990年代にかけての天文学的発見を支えた歴史的な「モデル」や「シミュレーション」を、現代の微分可能プログラミングフレームワーク Google JAX (Automatic Differentiation, GPU/TPU acceleration) を用いて再実装・可視化・検証するインタラクティブな体系書。
#
# # 📚 Volume 0: 黎明期と解析解 (Foundations: Analytic & Analog)
#
# テーマ: 計算機以前の直感、幾何学的近似、そして検証用の厳密解。
#
# # Ch.0-1: アナログ計算機による銀河相互作用 (Analog Computing)
#
# Ref: Holmberg, E. (1941). On the Clustering of Nebulae.Content: 光源（電球）の光度測定によって重力場（$1/r^2$）を代替した伝説的実験のデジタル再現。
#
# # Ch.0-2: 三体問題とカオスの発見 (The Onset of Chaos)
#
# Ref: Hénon, M., & Heiles, C. (1964). The applicability of the third integral of motion: Some numerical experiments.Content: 銀河ポテンシャル中の恒星軌道におけるポアンカレ断面とストレンジ・アトラクタの描画。
#
#  Ch.0-3:
#
#  制限三体問題と銀河の架け橋 (Restricted Three-Body Problem)Ref: Toomre, A., & Toomre, J. (1972). Galactic Bridges and Tails.Content: テスト粒子を用いたM51やアンテナ銀河の潮汐構造（Tidal Tails）の再現。
#
#  Ch.0-4:
#
#  爆風波の自己相似解 (Sedov-Taylor Blast Wave)Ref: Taylor, G. (1950); Sedov, L. I. (1959). Similarity and Dimensional Methods in Mechanics.Content: 超新星残骸の膨張則 ($R \propto t^{2/5}$) の解析解と数値解の比較。
#
#  Ch.0-5:
#
#  星形成の自己相似解 (Analytic Star Formation)
#
#  Ref A: Larson, R. B. (1969); Penston, M. V. (1969). (Runaway collapse)Ref B: Shu, F. H. (1977). Self-similar collapse of isothermal spheres. (Inside-out collapse)Content: 等温球の崩壊における「Larson-Penston解」と「Shu解」の境界条件による分岐をShooting法で解く。
#
#  Ch.0-6:
#
#  ボンディ降着と遷音速流 (Bondi Accretion)Ref: Bondi, H. (1952). On spherically symmetrical accretion.Content: 遷音速点（Sonic Point）を持つ定常降着流の解析解。🔭
#
#  Volume I:
#
#  宇宙論と大規模構造 (Cosmology & Large Scale Structure)
#
#  テーマ:
#
#  N体シミュレーションの進化。$N=300$ から $N=10^6$ へ。
#
#  Ch.1-1:
#
#  最初期の銀河団N体計算 (The First N-Body)
#
#  Ref: Peebles, P. J. E. (1970). Structure of the Coma Cluster of Galaxies.Content: わずか300個の粒子による銀河団のビリアル化過程。
#
#  Ch.1-2:
#
#  宇宙の網とCDMモデル (The Cosmic Web)Ref: Davis, M., Efstathiou, G., Frenk, C. S., & White, S. D. M. (1985). ("DEFW" / Gang of Four)Content: PM法 (Particle-Mesh) + FFTを用いた、冷たい暗黒物質 (CDM) 宇宙のフィラメント形成。
#
#  Ch.1-3:
#
#  ダークマターハローの普遍的プロファイル (NFW Profile)
#
#  Ref: Navarro, J. F., Frenk, C. S., & White, S. D. M. (1996). The Structure of Cold Dark Matter Halos.Content: 高解像度N体計算によるハロー密度分布の普遍性の発見と、FoF (Friends-of-Friends) アルゴリズムの実装。
#
#  Ch.1-4:
#
#  加速膨張宇宙のベイズ推定 (Accelerating Universe)Ref: Perlmutter, S., et al. (1999); Riess, A. G., et al. (1998).Content: Ia型超新星の観測データを用い、HMC (Hamiltonian Monte Carlo) で宇宙論パラメータ ($\Omega_m, \Omega_\Lambda$) を推定。✨
#
#  Volume II:
#
#  星間ガスと星・惑星形成 (ISM, Star & Planet Formation)
#
#  テーマ:
#
#  流体力学 (Hydrodynamics) と多相媒質。
#
#  Ch.2-1:
#
#  回転ガス雲の分裂 (Fragmentation)
#
#  Ref: Boss, A. P., & Bodenheimer, P. (1979). The fragmentation of isothermal interstellar clouds.Content: SPH法またはAMR法を用いた、回転するガス雲からの連星系形成。
#
#  Ch.2-2:
#
#  星間ガスの熱的不安定性 (Thermal Instability)
#
#  Ref: Field, G. B. (1965); Koyama, H., & Inutsuka, S. (2000/2002).Content: 加熱・冷却関数を含む流体計算による、冷たい雲（CNM）と暖かいガス（WNM）の相分離。
#
#  Ch.2-3:
#
#  スーパーバブルと銀河の噴水 (Superbubbles)
#
#  Ref: Tomisaka, K., & Ikeuchi, S. (1986).Content: 密度成層中での連続超新星爆発によるチムニー構造の形成。
#
#  Ch.2-4:
#
#  原始惑星系円盤とギャップ形成 (Disk-Planet Interaction)
#
#  Ref: Lin, D. N. C., & Papaloizou, J. (1986); Bryden, G., et al. (1999).Content: 惑星の重力による円盤ガスの排除（ギャップ）と惑星移動 (Migration)。
#
#  Ch.2-5:
#
#  微惑星の暴走的成長 (Runaway Growth)
#
#  Ref: Wetherill, G. W. (1985); Kokubo, E., & Ida, S. (1996).
#
#  Content: 衝突確率に基づく凝集方程式、またはN体計算による惑星質量分布の進化。
#
#  🌀 Volume III:
#
#  銀河ダイナミクス (Galactic Dynamics)
#
#  テーマ: 衝突、合体、そして構造の維持。
#
#  Ch.3-1:
#
#  密度波理論 (Density Wave Theory)
#
#  Ref: Lin, C. C., & Shu, F. H. (1964).Content: 固定ポテンシャル中での星の運動による渦巻腕の維持。
#
#  Ch.3-2:
#
#  銀河衝突とツリー法 (Galaxy Mergers)
#
#  Ref: Barnes, J., & Hut, P. (1986). A hierarchical O(N log N) force-calculation algorithm.Content: バーンズ・ハット法 (Tree code) を用いた銀河合体とスターバーストのトリガー。
#
#  Ch.3-3:
#
#  太陽系のカオス的進化 (Solar System Chaos)Ref: Laskar, J. (1989). A numerical experiment on the chaotic behaviour of the Solar System.Content: シンプレクティック積分を用いた惑星軌道の長期安定性解析とリアプノフ指数の計算。
#
#  ⚡ Volume IV: 高エネルギー天体と相対論 (High-Energy & Compact Objects)
#
#  テーマ:
#
#   極限環境下の流体と輻射。
#
#   Ch.4-1:
#
#   降着円盤の熱的不安定性 (Dwarf Nova Instability)
#
#   Ref: Mineshige, S., & Osaki, Y. (1983).Content: 降着円盤の「S字」平衡曲線によるリミットサイクル（矮新星アウトバースト）の1次元再現。
#
#   Ch.4-2:
#
#   パルサー磁気圏 (Pulsar Magnetosphere)
#
#   Ref: Krause-Polstorff, J., & Michel, F. C. (1985).Content: 回転する中性子星周囲の電荷分離と「Electrosphere」の緩和法による解法。
#
#   Ch.4-3:
#
#   超新星残骸のレイリー・テイラー不安定性 (SNR Instability)
#
#   Ref: Chevalier, R. A. (1982); Hachisu, I., et al. (1990).Content: SN 1987Aで見られた、爆発波面での物質混合（フィンガー構造）の2次元流体計算。
#
#   Ch.4-4:
#
#   潮汐破壊現象 (Tidal Disruption Events)Ref: Rees, M. J. (1988); Evans, C. R., & Kochanek, C. S. (1989).Content: ブラックホールによる恒星の破壊とデブリの降着シミュレーション。
#
#   Ch.4-5: ライン駆動風の不安定性 (Line-Driven Winds)Ref: Owocki, S. P., Castor, J. I., & Rybicki, G. B. (1988).Content: 大質量星の星風における非線形不安定性と「クランプ（ダマ）」の形成。
#
#   ⚗️ Volume V: 化学進化 (Chemical Evolution)
#
#   テーマ: 元素の起源と循環。宇宙の「料理」。
#
#   Ch.5-1:
#
#    銀河化学進化とG型星問題 (The G-Dwarf Problem)
#
#    Ref: Searle, L., & Sargent, W. L. W. (1972); Pagel, B. E. J. (1997).Content: 「閉じた箱 (Closed Box)」モデル vs 「ガス降着 (Infall)」モデルによる金属量分布の比較。
#
#    Ch.5-2:
#
#    元素存在比とタイムラグ (The Tinsley Diagram)
#
#    Ref: Tinsley, B. M. (1979). Stellar lifetimes and abundance ratios in chemical evolution.Content: SN IaとSN IIの発生タイムラグが生む [O/Fe] vs [Fe/H] 図の「折れ曲がり」の再現。
#
#    Ch.5-3:
#
#    星間分子生成ネットワーク (Molecular Chemistry)
#
#    Ref: Herbst, E., & Leung, C. M. (1989).Content: 数百の化学反応を含むStiffな微分方程式系による、暗黒星雲内での複雑な分子合成。
#
#    Ch.5-4:
#
#    ケモダイナミクス (Chemodynamics)
#
#    Ref: Hensler, G., & Burkert, A. (1990).Content: N体/SPHシミュレーションに化学進化を結合し、銀河内の金属量勾配の形成を追う。
